# %% [markdown]
# <a href="https://colab.research.google.com/github/JordanBaker78/Data201_JordanBaker/blob/main/Baker_Project1_week8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Project Name
# ##Jordan Baker
# ###Submission Date

# %% [markdown]
# ##Introduction
#
# The dataset for this project is a dataset that shows the budget history of the U.S. Department of Education from 2012 to 2019, including the President's Budget by major program, and shows State allocations by State and by program . The dataset was edited from a dataset found on Data.gov that orignated from the US Department of Education and the Office of finanace and Operations.
#
# (The original dataset was edited and formated into a usable csv dataset. No data is missing as a result of the edit)
#
# The population of interest is the programs in the Depratment of Education.
#
# There are no ethical or bias concerns with this data.
#
# Dataset citation: https://catalog.data.gov/dataset/u-s-department-of-education-budget-history-16b38/resource/a311e558-debb-454f-9745-7c283901adfc

# %% [markdown]
# ### Dataset Structure
# Use code to:
# - Show dataset size (rows and columns)
# - Describe what each row represents
#
# Create a table:
#
# | Name | Definition / Explanation | Type |
# |------|--------------------------|------|
# |      |                          |      |
#
# ---

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/JordanBaker78/Data201_JordanBaker/refs/heads/main/Project1/edhistory-2012-19%20-%20Sheet1.csv')
df.head()
df.info()

# %% [markdown]
# The dataset has 55 rows of the Major, Minor and other programs of the Education Department. The columns are the Presidents Budget and the Appropriation for the years 2012 to 2019.

# %% [markdown]
# ## 4. Data Analyses
#
# Include the following four analyses. Use full sentences and interpret results in context.
#
# ---
#
# ### a. Quantitative Variable (Descriptive)
# - State a research question
# - Explain why your data is appropriate
# - Use summary statistics and visualization
#
# Discuss:
# - Data cleaning or transformation
# - Measures of center and spread
# - Outliers
# - Shape of distribution (symmetric, skewed, etc.)
#
# ---
#
# ### b. Categorical Variable (Descriptive)
# - State a research question
# - Use summary statistics and visualization
#
# Discuss:
# - Data cleaning or transformation
# - Definition of levels
# - Interpretation of results
#
# ---
#
# ### c. Relationship Between Variables (Exploratory)
# - State a research question
# - Revise if needed during analysis
#
# Discuss:
# - Why you expect an association
# - Whether an association exists
# - Description of the relationship
#
# ---
#
# ### d. Nonparametric Inference (Median)
# - Use a random sample (~10%)
# - Explain your method
#
# Discuss:
# - Results of the inference
# - Interpretation
#
# ---

# %% [markdown]
# ## 5. Conclusions / Recommendations
# Summarize:
# - Key findings
# - Trends or associations
#
# Suggest:
# - Next steps for further analysis
#
# If nothing stands out, clearly state that.
#
# ---
